# %%
import geojson
import matplotlib.pyplot as plt
import geopandas as gpd

gj = gpd.read_file("PA2018.geojson")

# %%
print(gj.keys())
# Out:
# Index(['loc, prec', 'GEOID', 'county_id', 'precinct', 'G18DemSen', 'G18RepSen',
#        'G18LibSen', 'G18GreSen', 'G18IndSen', 'G18DemGov', 'G18RepGov',
#        'G18LibGov', 'G18GreGov', 'G18IndGov', 'G18DemHOR', 'G18RepHOR',
#        'G18LibHOR', 'G18GreHOR', 'G18IndHOR', 'geometry'],
#       dtype='object')

# %%
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (20, 10)

# %%
ax = gj.plot(color='blue')
